# %%
print("Hello World!")
# Out:
# Hello World!

# %%
5+8
# Out:
# 13

# %%
"hey"
# Out:
# 'hey'

# %% [markdown]
# This is a master class

# %% [markdown]
# Difference between Hardware and Software:
#
# Hardware: Physical components you can touch, like CPU and Keyboard.
# Software: Programs or instructions you cannot touch, like Microsoft Windows.
#
# Hardware performs tasks, while software controls how those tasks are performed.
